# %%
# !pip install .
# Out:
# Processing /home/lauraluebbert/projects/gget
# ...
#   Created wheel for gget: filename=gget-0.0.18-py3-none-any.whl size=827426 sha256=209fb173a1f8c7329456fea9ddedfff61c8965d97114937fc0c92d1f8cca8182
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kb9o0nyv/wheels/29/3d/33/db0a3cd90f191846910a7553fb5b876b9347924ee709a70c44
# Successfully built gget
# ...
#   Attempting uninstall: gget
#     Found existing installation: gget 0.0.18
#     Uninstalling gget-0.0.18:
#       Successfully uninstalled gget-0.0.18
# ...

# %%
import gget

# %%
gget.search("hi", "human")
# Out:
# 27 Apr 2022 14:48:47 INFO Fetching results from database: homo_sapiens_core_106_38
# 27 Apr 2022 14:48:49 INFO Note: NumExpr detected 48 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 27 Apr 2022 14:48:49 INFO NumExpr defaulting to 8 threads.
# 27 Apr 2022 14:48:49 INFO Query time: 3.2 seconds
# 27 Apr 2022 14:48:49 INFO Matches found: 1911
#            ensembl_id gene_name  \
# 0     ENSG00000003436      TFPI
# 1     ENSG00000005194   CIAPIN1
# 2     ENSG00000005700      IBTK
# 3     ENSG00000008394     MGST1
# 4     ENSG00000010310      GIPR
# ...               ...       ...
# 1906          LRG_846       OTC
# 1907           LRG_87      NCF1
# 1908          LRG_874      TPMT
# 1909           LRG_88      NCF2
# 1910           LRG_89    NFKBIA
#
#                                     ensembl_description  \
# 0     tissue factor pathway inhibitor [Source:HGNC S...
# 1     cytokine induced apoptosis inhibitor 1 [Source...
# ...

# %%
# gget.seq("ENSMUSG00000000223", seqtype="Transcript")

# %%
gget.info(["ENSMUSG00000000223", "ENSMUST00000113224.9", "ENSG00000008394", "LRG_87"], expand=True, wrap_text=True)
# Out:
# 27 Apr 2022 14:48:53 WARNING More than one UniProt ID was found for Ensembl ID 'ENSMUSG00000000223'. Only the first UniProt ID and its associated information will be returned.
# 27 Apr 2022 14:48:56 WARNING More than one UniProt ID was found for Ensembl ID 'ENSG00000008394'. Only the first UniProt ID and its associated information will be returned.
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# ~/projects/gget/gget/utils.py in get_uniprot_info(server, ensembl_ids, id_type)
#     233             # This will throw an EmptyDataError if no results were found
# --> 234             df = pd.read_csv(StringIO(res.decode("utf-8")), sep="\t")
#     235
#
# ...
