# %%
import gget
# %load_ext blackcellmagic
# Out:
# Sat Nov  5 16:04:28 2022 INFO Generating grammar tables from /Users/lauraluebbert/opt/anaconda3/lib/python3.9/site-packages/blib2to3/Grammar.txt
# Sat Nov  5 16:04:28 2022 INFO Writing grammar tables to /Users/lauraluebbert/Library/Caches/black/22.6.0/Grammar3.9.7.final.0.pickle
# Sat Nov  5 16:04:28 2022 INFO Writing failed: [Errno 2] No such file or directory: '/Users/lauraluebbert/Library/Caches/black/22.6.0/tmp5zfd0apz'
# Sat Nov  5 16:04:28 2022 INFO Generating grammar tables from /Users/lauraluebbert/opt/anaconda3/lib/python3.9/site-packages/blib2to3/PatternGrammar.txt
# Sat Nov  5 16:04:28 2022 INFO Writing grammar tables to /Users/lauraluebbert/Library/Caches/black/22.6.0/PatternGrammar3.9.7.final.0.pickle
# Sat Nov  5 16:04:28 2022 INFO Writing failed: [Errno 2] No such file or directory: '/Users/lauraluebbert/Library/Caches/black/22.6.0/tmpoagwb7cz'

# %%
df = gget.enrichr(
    genes= [
                "AIMP1",
                "MFHAS1",
                "BFAR",
                "FUNDC1",
                "AIMP2",
                "ASF1A",
                "FUNDC2",
                "TRMT112",
                "MTHFD2L"
            ],
    database= "ontology"
)

df.values.tolist()
# Out:
# Sat Nov  5 16:22:51 2022 INFO Performing Enichr analysis using database GO_Biological_Process_2021.
#     Please note that there might a more appropriate database for your application.
#     Go to https://maayanlab.cloud/Enrichr/#libraries for a full list of supported databases.
# [[1,
#   'translation (GO:0006412)',
#   9.675824801901589e-05,
#   46.872037914691944,
#   433.25207270512743,
#   ['AIMP1', 'AIMP2', 'TRMT112'],
#   0.00328427763325889,
#   'GO_Biological_Process_2021'],
#  [2,
#   'mitochondrion disassembly (GO:0061726)',
#   0.00011250476197410829,
#   167.7058823529412,
#   1524.868252317394,
#   ['FUNDC2', 'FUNDC1'],
#   0.00328427763325889,
#   'GO_Biological_Process_2021'],
#  [3,
#   'tRNA aminoacylation (GO:0043039)',
#   0.00012548254326066126,
#   158.37301587301587,
#   1422.719267111456,
#   ['AIMP1', 'AIMP2'],
#   0.00328427763325889,
#   'GO_Biological_Process_2021'],
#  [4,
#   'autophagy of mitochondrion (GO:0000422)',
#   0.0001391618496477865,
# ...
