# %%
from gget import gget
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
result = gget("GABA", "mouse")
# Out:
# Results fetched from database: mus_musculus_core_105_39
# Query time: 1.12 seconds
# Genes fetched: 29

# %%
result
# Out:
#             Ensembl_ID  Gene_name  \
# 0   ENSMUSG00000000560     Gabra2
# 1   ENSMUSG00000001260     Gabrg1
# 2   ENSMUSG00000007653     Gabrb2
# 3   ENSMUSG00000010803     Gabra1
# 4   ENSMUSG00000018567    Gabarap
# 5   ENSMUSG00000020159      Gabrp
# 6   ENSMUSG00000020428     Gabra6
# 7   ENSMUSG00000020436     Gabrg2
# 8   ENSMUSG00000023267     Gabrr2
# 9   ENSMUSG00000024462     Gabbr1
# 10  ENSMUSG00000028280     Gabrr1
# 11  ENSMUSG00000029054      Gabrd
# 12  ENSMUSG00000029211     Gabra4
# 13  ENSMUSG00000029212     Gabrb1
# 14  ENSMUSG00000030108    Slc6a13
# 15  ENSMUSG00000030109    Slc6a12
# 16  ENSMUSG00000030161  Gabarapl1
# 17  ENSMUSG00000030307    Slc6a11
# 18  ENSMUSG00000030310     Slc6a1
# 19  ENSMUSG00000031340      Gabre
# 20  ENSMUSG00000031343     Gabra3
# 21  ENSMUSG00000031344      Gabrq
# 22  ENSMUSG00000031950  Gabarapl2
# 23  ENSMUSG00000033676     Gabrb3
# 24  ENSMUSG00000037771    Slc32a1
# 25  ENSMUSG00000039809     Gabbr2
# ...
