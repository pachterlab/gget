# %%
from gget import gget 
from gget import ftpget

# %%
print(ftpget.__doc__)
# Out:
#     Function to fetch GTF and FASTA (cDNA and DNA) files from the Ensemble FTP site.
#
#     Parameters:
#     - species
#     Defines the species for which the files should be fetched in the format "<genus>_<species>",
#     e.g.species = "homo_sapiens".
#     - return_val
#     Defines which results to return. Possible entries are:
#     "json" - Returns all links in a json/dictionary format (default).
#     "gtf" - Returns the GTF FTP link as a string.
#     "cdna" - Returns the cDNA FTP link as a string.
#     "dna" - Returns the DNA FTP link as a string.
#
#     - release
#     Defines the Ensembl release number from which the files are fetched, e.g. release = 104.
#     (Ensembl releases < 48 are not suupported.)
#     By default, the latest Ensembl release is used.

# %%
ftpget("taeniopygia_guttata")
# Out:
# {'taeniopygia_guttata': {'transcriptome': {'ftp': 'http://ftp.ensembl.org/pub/release-105/fasta/taeniopygia_guttata/cdna/Taeniopygia_guttata.bTaeGut1_v1.p.cdna.all.fa.gz',
#    'ensembl_release': 105,
#    'release_date': '13-Oct-2021',
#    'release_time': '02:48',
#    'bytes': '27458905'},
#   'genome': {'ftp': 'http://ftp.ensembl.org/pub/release-105/fasta/taeniopygia_guttata/dna/Taeniopygia_guttata.bTaeGut1_v1.p.dna.toplevel.fa.gz',
#    'ensembl_release': 105,
#    'release_date': '12-Oct-2021',
#    'release_time': '10:40',
#    'bytes': ' 318945687'},
#   'annotation': {'ftp': 'http://ftp.ensembl.org/pub/release-105/gtf/taeniopygia_guttata/Taeniopygia_guttata.bTaeGut1_v1.p.105.gtf.gz',
#    'ensembl_release': 105,
#    'release_date': '16-Oct-2021',
#    'release_time': '00:51',
#    'bytes': '13460174'}}}

# %%
from gget import gget 
from gget import fetchtp

# %%
fetchtp("homo_sapiens")
# Out:
# {'homo_sapiens': {'transcriptome': {'ftp': 'http://ftp.ensembl.org/pub/release-105/fasta/homo_sapiens/cdna/Homo_sapiens.GRCh38.cdna.all.fa.gz',
#    'ensembl_release': 105,
#    'release_date': '18-Jun-2021',
#    'release_time': '12:56',
#    'bytes': '76085001'},
#   'genome': {'ftp': 'http://ftp.ensembl.org/pub/release-105/fasta/homo_sapiens/dna/Homo_sapiens.GRCh38.dna.primary_assembly.fa.gz',
#    'ensembl_release': 105,
#    'release_date': '18-Jun-2021',
#    'release_time': '13:38',
#    'bytes': ' 881211416'},
#   'annotation': {'ftp': 'http://ftp.ensembl.org/pub/release-105/gtf/homo_sapiens/Homo_sapiens.GRCh38.105.gtf.gz',
#    'ensembl_release': 105,
#    'release_date': '18-Jun-2021',
#    'release_time': '13:28',
#    'bytes': '50829040'}}}

# %%
gget(["gaba", "nmda"], "human")
# Out:
# Results fetched from database: homo_sapiens_core_105_38
# Query time: 3.95 seconds
# Genes fetched: 25
#          Ensembl_ID      Gene_name  \
# 0   ENSG00000034713      GABARAPL2
# 1   ENSG00000104853         CLPTM1
# 2   ENSG00000139112      GABARAPL1
# 3   ENSG00000170296        GABARAP
# 4   ENSG00000236942     RP11-6B6.3
# 5   ENSG00000238244      GABARAPL3
# 6   ENSG00000250330   CTC-422A18.2
# 7   ENSG00000254247   RP11-278I4.1
# 8   ENSG00000255365   RP11-776K3.1
# 9   ENSG00000255958  RP11-656E20.5
# 10  ENSG00000257852  RP11-843B15.1
# 11  ENSG00000258148     AC007115.3
# 12  ENSG00000262471    RP11-95P2.4
# 13  ENSG00000270708  RP11-568G11.5
# 14  ENSG00000276523  RP11-490B18.6
# 15  ENSG00000279980  RP11-154B12.4
# 16  ENSG00000105464         GRIN2D
# 17  ENSG00000116032         GRIN3B
# 18  ENSG00000161509         GRIN2C
# 19  ENSG00000165802           NSMF
# 20  ENSG00000176884          GRIN1
# 21  ENSG00000178719          GRINA
# 22  ENSG00000183454         GRIN2A
# ...
